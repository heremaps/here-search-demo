# %%
from here_search_demo.widgets.app import OneBoxMap
from here_search_demo.widgets.input_map import PositionMap
PositionMap.default_layout = {"height": "calc(100vh - 48px)"}
OneBoxMap(
    map_only=True, 
    on_map=True,
).run().show()
